# %%
from id import simm
#simm[corpus][ayah]
simm[0][0]['score']
# Out:
# 1

# %%
from data import ayat 
ayat[200][2]
# Out:
# 'الشَّهْرُ الْحَرَامُ بِالشَّهْرِ الْحَرَامِ وَالْحُرُمَاتُ قِصَاصٌ ۚ فَمَنِ اعْتَدَىٰ عَلَيْكُمْ فَاعْتَدُوا عَلَيْهِ بِمِثْلِ مَا اعْتَدَىٰ عَلَيْكُمْ ۚ وَاتَّقُوا اللَّهَ وَاعْلَمُوا أَنَّ اللَّهَ مَعَ الْمُتَّقِينَ'

# %%
def idtoayat(id):
    print("(QS.{}:{}) {}".format(ayat[id][0],ayat[id][1],ayat[id][2]))

# %%
idtoayat(2000)
# Out:
# (QS.16:100) إِنَّمَا سُلْطَانُهُ عَلَى الَّذِينَ يَتَوَلَّوْنَهُ وَالَّذِينَ هُمْ بِهِ مُشْرِكُونَ

# %%
# if score in simm[corpus][id] > 0.999 replace it with 1
# if score in simm[corpus][id] < 0.001 replace it with 0
for i in range(len(simm)):
    for j in range(0,len(simm[i])):
        if simm[i][j]['score'] > 0.999:
            simm[i][j]['score'] = 1
        elif simm[i][j]['score'] < 0.001:
            simm[i][j]['score'] = 0

# %%
with open("data.py", "r") as f:
    data = f.read()
    data = data.replace("], [", "], \n[")
with open("data.py", "w") as f:
    f.write(data)

# %%
# change data type of ayat[0][1] to be int
for i in range(len(ayat)):
    ayat[i][1] = int(ayat[i][1])
    ayat[i][0] = int(ayat[i][0])

# %%
with open("data.py", "w") as f:
    f.write("ayat = ")
    f.write(str(ayat))

# %%
listofscore = []
for i in range(len(simm)):
    score = []
    for j in range(0,len(simm[i])):
        score.append(simm[i][j]['score'])
    listofscore.append(score)

# %%
len(listofscore)
# Out:
# 6236

# %%
import json

# %%
with open("en.md", "r") as f:
    en = f.read()
    en = en.split("#")
    en = en.replace("\n\n", "\n")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [11], line 4
#       2 en = f.read()
#       3 en = en.split("#")
# ----> 4 en = en.replace("\n\n", "\n")
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
import re 
def clean(text):
    # clean "\n" "#" and number 
    text = re.sub(r"\d\n\n", "", text)
    text = re.sub(r"#", "", text)
    return text

# %%
em = []
for i in en: 
    en.app
# Out:
#  In the Name of Allah, the All-beneficent, the All-merciful.
#
#
#  All praise belongs to Allah, Lord of all the worlds,
#
#
#  the All-beneficent, the All-merciful,
#
#
#  Master of the Day of Retribution.
#
#
#  You [alone] do we worship, and to You [alone] do we turn for help.
#
#
#  Guide us on the straight path,
#
#
#  the path of those whom You have blessed — such as have not incurred Your wrath, nor are astray.
#
#
#  Alif, Lam, Mim.
#
#
#  This is the Book, there is no doubt in it, a guidance to the Godwary,
#
#
#  1who believe in the Unseen, maintain the prayer, and spend out of what We have provided for them;
#
#
#  1and who believe in what has been sent down to you and what was sent down before you, and are certain of the Hereafter.
#
#
#  1Those follow their Lord’s guidance and it is they who are the felicitous.
#
#
#  1As for the faithless, it is the same to them whether you warn them or do not warn them, they will not have faith.
#
#
# ...

# %% [markdown]
# # create interlink md file
# []: # Language: markdown
# []: # Path: test/quranapp/data/interlink.md

# %%
import os 
import json 
import re
import sys

# %%
with open("en.mdx", "w") as f:
    for i in range(len(en)):
        f.write(clean(en[i]))
