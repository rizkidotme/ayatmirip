# %%
# read index.html 
with open('index.html', 'r') as f:
    html = f.read()
    html = html.replace('\"', '')
with open('index.html', 'w') as f:
    f.write(html)
# Out:
# Bad pipe message: %s [b'\xaa\xe6\x1af\xbe\x081r\x19\x1a\xca\x16\x84\xc5\x05\xf6%\x1e \xe6\x04']
# Bad pipe message: %s [b'\x1ck\xd8\x94F\xa12\xa4\x81;\xbd\xfaTh\xc5\x92P\xaf \x0c\x8c\x92\x15\xe8\x18\xcck^\x9c\x99rz\x7f\xe0\x8f\xd2\x18\xfbDV\x80|\x89\x8c3k\xd6G\xb7\x9cc\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 ][\x0c\xa2\xeb\xae\xec1\x87g\xbf\x82\\F#\xa4\xc4\xeeY\x0b\x9e7']
# ...
